# %% [markdown]
# # Data preparation

# %%
import random

# %% [markdown]
# ### Read and clean dutch data

# %%
nl_text = open("data_letterfrequenties/nl_tekst.txt", "r")
nl_lines = nl_text.readlines()

# %%
dutch_lines = []

# %%
for line in nl_lines:
   # For Python3, use print(line)
   if line != '\n' and '  ' not in line:
        dutch_lines.append([line, 'dutch'])
   else:
        nl_lines.remove(line)

# %% [markdown]
# ### Read and clean englisch data

# %%
eng_text = open("data_letterfrequenties/alice.txt", "r")
eng_lines = eng_text.readlines()

# %%
english_lines = []

# %%
for line in eng_lines:
   # For Python3, use print(line)
   if line != '\n' and '  ' not in line:
        english_lines.append([line, 'english'])
   else:
        eng_lines.remove(line)

# %% [markdown]
# ### Combine both text files

# %%
train_text = dutch_lines + english_lines

# %%
random.shuffle(train_text)

# %%
for i in train_text:
    print(i)
# Out:
# ['hun voor hun moeite een vrijkaartje gaf.\n', 'dutch']
# ['rondom hen.\n', 'dutch']
# ["leert wel ter harte nemen. Het weet maat te houden en voelt wanneer 't\n", 'dutch']
# ['huiskamer!\n', 'dutch']
# ['VII--A MAD TEA-PARTY\n', 'english']
# ["niet 'n beetje voortmaakt met me er uit te laten, dàn zie je van dit\n", 'dutch']
# ['upon a low curtain she had not noticed before, and behind it was a\n', 'english']
# ['en met hunne achting, die ook ik u niet zal onthouden, wanneer ge op\n', 'dutch']
# ['anders zal ik u toonen hoe hij een rauwe kip naar binnen werkt."\n', 'dutch']
# ['beer te moeten worden en met wie weet welke groote honden te moeten\n', 'dutch']
# ['ontwricht hadden. Toen slenterden ze verder langs den rivieroever.\n', 'dutch']
# ['very much out of the way to hear the Rabbit say to itself, "Oh dear! Oh\n', 'english']
# ['hem die men veronderstelde dat zoo treurig aan zijn einde kwam, want\n', 'dutch']
# ...

# %%
for i in dutch_lines:
    print(i)
# Out:
# ['Paul.\n', 'dutch']
# ['In Frankrijk, in de provincie Normandië, woonde de familie Steenvoorde:\n', 'dutch']
# ['papa, mama en drie kinderen, twee meisjes en een jongen. De jongen\n', 'dutch']
# ['heette Paul; hij was de oudste van het drietal, maar jammer genoeg, bij\n', 'dutch']
# ['lange na de wijste niet.\n', 'dutch']
# ['heengezonden, maar als hij slechts eenigszins kon, wandelde hij de\n', 'dutch']
# ['schooldeur voorbij, om liever met allerlei straatjongens buiten te\n', 'dutch']
# ['spelen. En als hij eens een enkele keer naar binnen stapte, dan was\n', 'dutch']
# ['hij al binnen een kwartier weer op straat gezet. Paul kende geen\n', 'dutch']
# ['gehoorzaamheid; hij deed precies en alleen wat hij zelf wilde en daar\n', 'dutch']
# ['andere menschen gewoonlijk juist het tegenovergestelde verlangden, kreeg\n', 'dutch']
# ['Paul voortdurend straf. Hij bleef echter onverbeterlijk, welke straf\n', 'dutch']
# ...
